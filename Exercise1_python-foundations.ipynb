# %%
jzo = int(8)
# You don't need to type int, when the value is int, Python gets it automatically when you write it down.
ice_cream_rating = 9
sleeping_rating = 10

# %%
first_name = "Juan"

# %%
last_name = " Zotes"

# %%
my_name = first_name+last_name

# %%
from statistics import mean

happiness_rating = mean([ice_cream_rating,sleeping_rating])
print(happiness_rating)
# Out:
# 9.5

# %%
happiness_rating2 = (ice_cream_rating+sleeping_rating)/2
print(happiness_rating)
# Out:
# 9.5

# %%
type(ice_cream_rating)
type(sleeping_rating)
# Out:
# int

# %%
type(happiness_rating)
type(happiness_rating2)
# Out:
# float

# %%
int(happiness_rating)
# Out:
# 9

# %%
round(happiness_rating)
# Out:
# 10

# %%
type(jzo)
# Out:
# int

# %%
# Yes, all the  data types make sense. The mean-average became float  because the result was not an integer.

# %%
print("My name is", first_name, "and I give eating ice cream a score of", ice_cream_rating, "out of 10!")
print("I am", my_name, "and my sleeping enjoyment rating is", sleeping_rating, "out of 10!")
print("Based on the factor above, my happiness rating is", happiness_rating, "out of 10,", 10.0*happiness_rating, "%!")
# Out:
# My name is Juan and I give eating ice cream a score of 9 out of 10!
# I am Juan Zotes and my sleeping enjoyment rating is 10 out of 10!
# Based on the factor above, my happiness rating is 9.5 out of 10, 95.0 %!
